# %% [markdown]
# Api_key - Data 05-08-2024 (data de maior valor desde 03/2021)

# %%
url = "https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarDia(dataCotacao=@dataCotacao)?@dataCotacao='08-05-2024'&$skip=0&$format=json&$select=cotacaoCompra,cotacaoVenda,dataHoraCotacao"

# %% [markdown]
# Importação das Bibliotecas

# %%
import pandas as pd  #possibilita manipulação e análise de dados
import requests  #possibilita integração com serviços web, solicitações HTTP consumir dados de APIs
import json  #manipular arquivo json

# %% [markdown]
# Função para extrair os dados da API

# %%
def requisicao_api(url):
  resposta = requests.get(url)

  if resposta.status_code == 200:      #sucesso na requisição
    dados = resposta.json()
    print('Status Code:', resposta.status_code)
    with open('resultado_Data.json', 'w', encoding='utf-8') as arquivo:   #salvar arquivo json
      json.dump(dados, arquivo, ensure_ascii=False, indent=4)

  else:
    print('Status Code:', resposta.status_code)

# %%
requisicao_api(url)
# Out:
# Status Code: 200

# %% [markdown]
# Conversão em dataframe (para Json)

# %%
jsondata = pd.read_json('resultado_Data.json')

# %%
data = jsondata['value']
dados_df = pd.json_normalize(data)

# %%
dados_df.head()
# Out:
#    cotacaoCompra  cotacaoVenda         dataHoraCotacao
# 0          5.764        5.7646  2024-08-05 13:04:30.94

# %% [markdown]
# Exportando para CSV

# %%
df = pd.json_normalize(jsondata['value']) ; 
df.to_csv("resultado_Data.csv", index=False)
